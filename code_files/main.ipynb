# %%
# !pip install -qq langchain langchain-community langchain-openai langchain-chroma transformers openai python-dotenv
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
import pandas as pd
df = pd.read_csv("/content/books_cleaned.csv")

# %%
df['tagged_description'].to_csv('tagged_description.txt',sep='\n',
                        index=False,
                        header = False)

# %%
from langchain_core.documents import Document
raw_documents = TextLoader("tagged_description.txt").load()
lines = raw_documents[0].page_content.split("\n")
documents = [Document(page_content=line.strip()) for line in lines if line.strip()]

# %%
# !pip install -U langchain-huggingface sentence-transformers
from langchain_huggingface import HuggingFaceEmbeddings
embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

db_books = Chroma.from_documents(
    documents,
    embedding=embedding
)

# %%
query = "buddhism enlightenment consciousness religious liberation"
docs = db_books.similarity_search(query,k=10)
docs
# Out:
# [Document(id='69155875-a0a2-4292-a93f-b579002387f6', metadata={}, page_content='9780835608305 This new edition of critically acclaimed essays explores possible breakthroughs in the direction of reaching a liberated and enlightened consciousness. With a new preface and new final chapter. An invaluable collection of essays by the foremost religious writer in America today.'),
#  Document(id='c26004d0-3761-45d6-9493-e1bb94c7f097', metadata={}, page_content='9780767901574 Drawing on three decades of learning from the spiritual masters of Asia, an American lama illuminates the sacred wisdom and practices of Buddhism and shows readers how to integrate them into their lives, relationships, and careers. Reprint. $50,000 ad/promo. Tour.'),
#  Document(id='b97724dd-6e6d-43fe-93ef-739b9c1228d7', metadata={}, page_content="9780971500747 Explores the ego's expressions and inherent limitations and gives detailed explanations and instructions on how to transcend them. It expands the understanding of the levels of consciousness as presented in the wiedely-acclaimed Map of Consciousness. The book focuses on the individual, and studies the experiential subjective blocks to the advancement of awareness, at each level of consciousness. This leads to progressive spiritual awareness and on to higher levels of consciousness, providing specific steps for transcending each level, preparatory to advanced states such as Enlightenment itself. By analyzing the various obstacles and levels to be transcended, certain principles that support spiritual evolution are self-revealing. This book si therefore a practical manual rather than a comprehensive analysis."),
#  Document(id='d24fd0c2-a05e-4b4c-aec5-cf1678089347', metadata={}, page_content='9780143034360 A portrait of the Buddha explores his identities both as an archetypal religious icon and as a man, chronicling his journey from his decision to leave a life of ease and power to his attainment of spiritual enlightenment.'),
#  Document(id='bdde2501-a9bd-4de6-883e-a1e0d8f2cdda', metadata={}, page_content='9781573221115 Drawing on more that 2,500 years of Buddhist tradition and teaching, the spiritual leader demonstrates how to confront the negative emotions, stresses, and obstacles of everyday life in order to find the source of inner peace.'),
#  Document(id='3e32b96e-a79c-480e-b0cf-aca1295dc062', metadata={}, page_content='"9780971500761 Finalizes and further clarifies the true nature and core of the condition termed ""Enlightenment."" It is primarily an instruction manual for the serious spiritual devotee, and reveals information only known by those who have transcended the ego to reach Divine Realization. This is the inner route from the self to the Self. The subjective states of the mystic are of great interest, but historically never have been clarified to the degree presented in this semi-autobiographical account that also provides the means by which to identify their rare occurrence, and thus describe the core characteristics of Spiritual Truth. Devoid of ecclesiastical doctrine or religious belief systems, the pristine essence of all spiritual Truth is revealed in its purity with unprecedcented clarity."'),
#  Document(id='1da42c70-8f87-4e61-ac43-7c1dbc7a68bd', metadata={}, page_content='9780967469782 While the notion that “happiness can found within oneself” has recently become popular, Buddhism has taught for thousands of years that every person is a Buddha, or enlightened being, and has the potential for true and lasting happiness. Through real-life examples, the authors explain how adopting this outlook has positive effects on one’s health, relationships, and career, and gives new insights into world environmental concerns, peace issues, and other major social problems.'),
#  Document(id='5fe5ecb7-cb66-43d6-8505-7f7bdaf07efa', metadata={}, page_content="9780285647473 The key book in our quest for understanding of ourselves and our lives.What differences are there in Eastern and Western thought regarding the nature of the human mind and our role in the cosmos? How can Zen and psychoanalysis help us in our struggle to realise our full potential as human beings and members of society?Erich Fromm's seminal work among contemporary efforts to resolve our spiritual crisis results here in the great achievement of a language to reveal the contributions of Zen and psychoanalysis to our 'struggle to be fully born'. He shows how both can teach us in their different ways to live our lives rather than be 'lived by them'.D.T. Suzuki explains with profound and gentle wisdom how Western materialism and intellectualism contrast with the Eastern concept of acceptance as the basis of well-being for the 'whole man'. His illuminating discussion of the unconscious and the self shed fresh light on our understanding of our own nature.Combined with Richard De Martino's clear account of the psychology of Zen, these writings make up a work of brilliance and value that has much to help us in our quest for understanding."),
#  Document(id='45066f08-0d62-4f82-8a68-ecae14441cd0', metadata={}, page_content="9781577314035 This previously unpublished title shows Campbell's remarkable mind engaged with a favorite topic, the myths and metaphors of Asian religions. The book collects seven lectures and articles ranging from the ancient Hindu Vedas to Zen koans, Tantric yoga, and the Tibetan Book of the Dead. Campbell conveys complex insights through warm, accessible storytelling, revealing the intricacies and secrets of his subjects with his typical enthusiasm.--From publisher description."),
#  Document(id='d15e1399-0cad-4f41-8fc5-e9a0ff7aeaa5', metadata={}, page_content='"9780861711765 The author plumbs the ""Eightfold Path"" of Buddhism for advice on how to live life with the proper attention to understanding, thinking, speech, action, livelihood, effort, mindfulness, and concentration."')]

# %%
df[df["isbn13"]==int(docs[0].page_content.split()[0].strip())]
# Out:
#              isbn13      isbn10                       title       authors  \
# 4096  9780835608305  0835608301  Beyond the Postmodern Mind  Huston Smith
#
#       categories                                          thumbnail  \
# 4096  Philosophy  http://books.google.com/books/content?id=lKnLB...
#
#                                             description  published_year  \
# 4096  This new edition of critically acclaimed essay...          2003.0
#
#       average_rating  num_pages  ratings_count  \
# 4096            4.21      295.0           67.0
#
#                                        titles_subtitles  \
# 4096  Beyond the Postmodern Mind: The Place of Meani...
#
#                                      tagged_description
# 4096  9780835608305 This new edition of critically a...

# %%
def retrieve_semantic_recommendations(query: str, top_k: int = 10) -> pd.DataFrame:
    docs = db_books.similarity_search(query, k=top_k)

    book_list = []
    for i in range(len(docs)):
        isbn = docs[i].page_content.split()[0].strip().strip('"')
        book_list.append(int(isbn))

    return df[df["isbn13"].isin(book_list)].head(top_k)

# %%
retrieve_semantic_recommendations("most meticulous accounts of Roman Empire")
# Out:
#              isbn13      isbn10                               title  \
# 115   9780060510855  0060510854                              Caesar
# 671   9780140442410  0140442413                            Germania
# 963   9780192833006  0192833006                Agricola and Germany
# 1223  9780312320195  0312320191   SPQR VI: Nobody Loves a Centurion
# 1753  9780380710829  038071082X                     The Grass Crown
# 3043  9780674990333  0674990331                         De officiis
# 3074  9780679724773  067972477X                         I, Claudius
# 3182  9780688093686  068809368X               The first man in Rome
# 3564  9780760768952  0760768951                The Conquest of Gaul
# 4648  9781565849426  1565849426  The Assassination of Julius Caesar
#
#                                      authors            categories  \
# 115                       Colleen McCullough               Fiction
# 671                        Cornelius Tacitus               History
# 963                                  Tacitus  Literary Collections
# 1223                     John Maddox Roberts               Fiction
# 1753                      Colleen McCullough               Fiction
# 3043     Marcus Tullius Cicero;Walter Miller               Fiction
# 3074                           Robert Graves               Fiction
# 3182                      Colleen McCullough               Fiction
# 3564  Julius Caesar;F. P. Long;Cheryl Walker               History
# 4648                         Michael Parenti               History
#
#                                               thumbnail  \
# 115   http://books.google.com/books/content?id=aoH_-...
# 671   http://books.google.com/books/content?id=-TCOs...
# 963   http://books.google.com/books/content?id=wS7IJ...
# 1223  http://books.google.com/books/content?id=Wkowm...
# 1753  http://books.google.com/books/content?id=Kt3gN...
# 3043  http://books.google.com/books/content?id=4lN0A...
# 3074  http://books.google.com/books/content?id=cRzDT...
# 3182  http://books.google.com/books/content?id=kMRmP...
# 3564  http://books.google.com/books/content?id=AYuHP...
# 4648  http://books.google.com/books/content?id=xApsW...
#
#                                             description  published_year  \
# 115   A fictional portrait of Julius Caesar follows ...          2003.0
# 671   The Agricola is both a portrait of Julius Agri...          1970.0
# 963   Cornelius Tacitus, Rome's greatest historian, ...          1999.0
# 1223  Like so many young men in later generations, R...          2003.0
# 1753  The lives of ancient Rome's men--general Gaius...          1992.0
# 3043  Cicero (Marcus Tullius, 106–43 BCE), Roman law...          1975.0
# 3074  The emperor Claudius tells of his life during ...          1989.0
# 3182  A story tracing the creation of Republican Rom...          1990.0
# 3564  Among the most durable and engaging texts in w...          2005.0
# 4648  Parenti presents a story of popular resistance...          2004.0
#
#       average_rating  num_pages  ratings_count  \
# 115             4.36      928.0         5825.0
# 671             3.98      174.0         3895.0
# 963             3.98      224.0           25.0
# 1223            4.13      288.0          626.0
# 1753            4.29     1104.0         9397.0
# 3043            3.95      448.0          104.0
# 3074            4.27      468.0        43469.0
# 3182            4.10      896.0          294.0
# 3564            3.99      288.0           50.0
# 4648            4.14      276.0          628.0
#
#                                        titles_subtitles  \
# 115                                     Caesar: A Novel
# 671                                            Germania
# 963                                Agricola and Germany
# 1223                  SPQR VI: Nobody Loves a Centurion
# 1753                                    The Grass Crown
# 3043            De officiis: C. Philosophical Treatises
# 3074  I, Claudius: From the Autobiography of Tiberiu...
# 3182                              The first man in Rome
# 3564                               The Conquest of Gaul
# 4648  The Assassination of Julius Caesar: A People's...
#
#                                      tagged_description
# 115   9780060510855 A fictional portrait of Julius C...
# 671   9780140442410 The Agricola is both a portrait ...
# 963   9780192833006 Cornelius Tacitus, Rome's greate...
# 1223  9780312320195 Like so many young men in later ...
# 1753  9780380710829 The lives of ancient Rome's men-...
# 3043  9780674990333 Cicero (Marcus Tullius, 106–43 B...
# 3074  9780679724773 The emperor Claudius tells of hi...
# 3182  9780688093686 A story tracing the creation of ...
# 3564  9780760768952 Among the most durable and engag...
# 4648  9781565849426 Parenti presents a story of popu...

# %%
len(df['categories'].unique())
# Out:
# 480

# %%
categories = df['categories'].value_counts().reset_index().query("count >= 50")['categories']
categories.tolist()
# Out:
# ['Fiction',
#  'Juvenile Fiction',
#  'Biography & Autobiography',
#  'History',
#  'Literary Criticism',
#  'Religion',
#  'Philosophy',
#  'Comics & Graphic Novels',
#  'Drama',
#  'Juvenile Nonfiction',
#  'Science',
#  'Poetry',
#  'Literary Collections']

# %%
categ_mapping = {'Fiction':"fiction",
 'Juvenile Fiction':"children fiction",
 'Biography & Autobiography':"Nonfiction",
 'History':"Nonfiction",
 'Literary Criticism':"Nonfiction",
 'Religion':"Nonfiction",
 'Philosophy':"Nonfiction",
 'Comics & Graphic Novels':"fiction",
 'Drama':"fiction",
 'Juvenile Nonfiction':"children Nonfiction",
 'Science':"Nonfiction",
 'Poetry':"fiction"}

# %%
df['simple_categ'] = df['categories'].map(categ_mapping)
df['simple_categ']
# Out:
# 0          fiction
# 1              NaN
# 2          fiction
# 3              NaN
# 4              NaN
#            ...
# 5192           NaN
# 5193           NaN
# 5194           NaN
# 5195    Nonfiction
# 5196    Nonfiction
# Name: simple_categ, Length: 5197, dtype: object

# %%
len(df[~df['simple_categ'].isna()]),len(df[df['simple_categ'].isna()])
# Out:
# (3743, 1454)

# %%
from transformers import pipeline
categories = ['fiction','Nonfiction']
classifier = pipeline("zero-shot-classification",model='facebook/bart-large-mnli',device=0)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
import numpy as np
def generate_prediction(seq,categories):
    predictions = classifier(seq,categories)
    max_index = np.argmax(predictions['scores'])
    max_label = predictions['labels'][max_index]
    return max_label
generate_prediction('budhhism spirituality',categories)
# Out:
# 'fiction'

# %%
df.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'authors', 'categories', 'thumbnail',
#        'description', 'published_year', 'average_rating', 'num_pages',
#        'ratings_count', 'titles_subtitles', 'tagged_description',
#        'simple_categ'],
#       dtype='object')

# %%
def generate_prediction(seq,categories):
    predictions = classifier(seq,categories)
    max_index = np.argmax(predictions['scores'])
    max_label = predictions['labels'][max_index]
    return max_label

from tqdm.auto import tqdm
actual_cat = []
predicted_cat = []

for i in tqdm(range(0,300)):
    seq = df.loc[df['simple_categ']=='fiction','description'].reset_index(drop=True)[i]
    predicted_cat.append(generate_prediction(seq,categories))
    actual_cat += ["fiction"]
for i in tqdm(range(0,300)):
    seq = df.loc[df['simple_categ']=='Nonfiction','description'].reset_index(drop=True)[i]
    predicted_cat.append(generate_prediction(seq,categories))
    actual_cat += ["Nonfiction"]
eval_data = pd.DataFrame({'prediction':predicted_cat,'actual_cat':actual_cat})
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
isbn = []
predicted_cats = []
missing_cats = df.loc[df['simple_categ'].isna(),['isbn13','description']].reset_index(drop=True)

# %%
for i in tqdm(range(0,len(missing_cats))):
    seq = missing_cats['description'][i]
    predicted_cats += [generate_prediction(seq,categories)]
    isbn +=  [missing_cats['isbn13'][i]]
# Out:
#   0%|          | 0/1454 [00:00<?, ?it/s]

# %%
miss_cats = pd.DataFrame({'isbn13':isbn,'predicted_categ':predicted_cats})
miss_cats.head()
# Out:
#           isbn13 predicted_categ
# 0  9780002261982         fiction
# 1  9780006280897      Nonfiction
# 2  9780006280934      Nonfiction
# 3  9780006380832      Nonfiction
# 4  9780006470229         fiction

# %%
df = pd.merge(df,miss_cats, on='isbn13',how='left')
len(df)
# Out:
# 5197

# %%
df["simple_categ_x"] = np.where(df["simple_categ"].isna(),df["predicted_categ"],df["simple_categ"])
df.isna().sum()
# Out:
# isbn13                   0
# isbn10                   0
# title                    0
# authors                 32
# categories              30
# thumbnail              166
# description              0
# published_year           0
# average_rating           0
# num_pages                0
# ratings_count            0
# titles_subtitles         0
# tagged_description       0
# simple_categ          1454
# predicted_categ       3743
# simple_categ_x           0
# dtype: int64

# %%
df.drop(['predicted_categ','simple_categ'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'authors', 'categories', 'thumbnail',
#        'description', 'published_year', 'average_rating', 'num_pages',
#        'ratings_count', 'titles_subtitles', 'tagged_description',
#        'simple_categ_x'],
#       dtype='object')

# %%
df['simple_categ_x'].value_counts()
# Out:
# simple_categ_x
# fiction                2722
# Nonfiction             2028
# children fiction        390
# children Nonfiction      57
# Name: count, dtype: int64

# %%
df[df["categories"].str.lower().isin([
    "fantasy",
    "horror","comedy"
])]
# Out:
#              isbn13      isbn10                                     title  \
# 478   9780099422341  0099422344                            Yeats is Dead!
# 491   9780099446729  0099446723                            Blackwood Farm
# 1090  9780261102422  0261102427                          The Silmarillion
# 2845  9780575075597  0575075597                                    Replay
# 2860  9780590254762  0590254766      The lion, the witch and the wardrobe
# 3288  9780739423851  0739423851                           Wizard's Castle
# 4483  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 4979  9781841494081  1841494089            The Darkness that Comes Before
#
#                         authors categories  \
# 478             Joseph O'Connor     Comedy
# 491                   Anne Rice     Horror
# 1090  John Ronald Reuel Tolkien    Fantasy
# 2845               Ken Grimwood    Fantasy
# 2860        Clive Staples Lewis    Fantasy
# 3288          Diana Wynne Jones    Fantasy
# 4483               Terry Brooks    Fantasy
# 4979            R. Scott Bakker    Fantasy
#
#                                               thumbnail  \
# 478   http://books.google.com/books/content?id=DrE3I...
# 491   http://books.google.com/books/content?id=cIn8T...
# 1090  http://books.google.com/books/content?id=22ePu...
# 2845  http://books.google.com/books/content?id=9vmNP...
# 2860                                                NaN
# 3288  http://books.google.com/books/content?id=hB7hA...
# 4483  http://books.google.com/books/content?id=jqVsA...
# 4979  http://books.google.com/books/content?id=BG8qG...
#
#                                             description  published_year  \
# 478   In aid of Amnesty International, this is a bri...          2002.0
# 491   Lestat Is Back, Saviour And Demon, Presiding O...          2003.0
# 1090  Tolkien's Silmarillion is the core work of the...          1999.0
# 2845  At forty-three Jeff Winston is tired of his lo...          2005.0
# 2860  Four English school children enter the magic l...          1995.0
# 3288  Howl's moving castle - Eldest of three sisters...          2002.0
# 4483  When the body of a half-drowned elf is found f...          2004.0
# 4979  A score of centuries has passed since the Firs...          2005.0
#
#       average_rating  num_pages  ratings_count  \
# 478             3.39      298.0           34.0
# 491             3.86      774.0        26145.0
# 1090            3.91      384.0          253.0
# 2845            4.16      272.0          412.0
# 2860            4.21      189.0          860.0
# 3288            4.44      376.0          439.0
# 4483            4.26     1260.0           84.0
# 4979            3.79      638.0          317.0
#
#                                       titles_subtitles  \
# 478   Yeats is Dead!: A Novel by Fifteen Irish Writers
# 491                                     Blackwood Farm
# 1090                                  The Silmarillion
# 2845                                            Replay
# 2860              The lion, the witch and the wardrobe
# 3288                                   Wizard's Castle
# 4483          The Voyage of the Jerle Shannara Trilogy
# 4979                    The Darkness that Comes Before
#
#                                      tagged_description simple_categ_x
# 478   9780099422341 In aid of Amnesty International,...        fiction
# 491   9780099446729 Lestat Is Back, Saviour And Demo...        fiction
# 1090  9780261102422 Tolkien's Silmarillion is the co...        fiction
# 2845  9780575075597 At forty-three Jeff Winston is t...     Nonfiction
# 2860  9780590254762 Four English school children ent...     Nonfiction
# 3288  9780739423851 Howl's moving castle - Eldest of...     Nonfiction
# 4483  9781416502043 When the body of a half-drowned ...     Nonfiction
# 4979  9781841494081 A score of centuries has passed ...     Nonfiction

# %%
df.to_csv('books_cleaned_with_categ.csv',index=False)
